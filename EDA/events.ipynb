# %% [markdown]
# # Events Table
#
# ## As is
#
# There are two sheets for events Leaders and Partners Dinner and 2019 Market Re-Cap with the following columns accross both:
#
# - Name
# - E-mail
# - Attendee Status
#
#
# ## To be
#
# Connection to this dataset will be contact id, but I think the events/marketing participants should be a dimentional table like contast - only modified when new events are made. There so, two tables are needed: dimentions and participants.
#
# ### Events dim
#
# Data model:
#
# -
# - Event ID: Unique event id (FK)
# - Event Name: Name of event (String)
# - Year: Year it was held (Integer)
#
# Reason for this table if for expansion of differetn events - I was provided only two but it can expand
#
#
# ### Event Participants/ Marketing Participants
#
# - Event ID (PK)
# - Contact ID (FK) (String)
# - Event Year (String)
#     - if multiple times a year: Event year, month, day
#     - Need to know the year from partners meeting
# - Attendee Staus (String)
#
#
#
# From the data provided I think this is the best solution  - if more markeing event have been done / more date is collected the schema can be evolved

# %%
import pandas as pd

# %%
path = "..\data\Events.xlsx"
sheet = pd.read_excel(path)

# %%
display(sheet)
# Out:
#                Name                         E-mail Attendee Status
# 0     Rob Baltimore  BBaltimore@harriswilliams.com          RSVP'd
# 1       Brian Lucas      blucas@harriswilliams.com        Declined
# 2       Luke Semple     lsemple@harriswilliams.com      Checked In
# 3    Andrew Spitzer    aspitzer@harriswilliams.com         No Show
# 4       Derek Lewis      dlewis@harriswilliams.com        Declined
# ..              ...                            ...             ...
# 66  Kiran Paruchuru         kparuchuru@rwbaird.com      Checked In
# 67     Jordan Klein             jklein@rwbaird.com      Checked In
# 68        Drew Snow              asnow@rwbaird.com      Checked In
# 69      Daniel Alfe              dalfe@rwbaird.com          RSVP'd
# 70  Matthew Kessler           mkessler@rwbaird.com          RSVP'd
#
# [71 rows x 3 columns]

# %%
print(sheet.describe())
# Emails have to be unique but with the contact lets make it a unique if
# Out:
#                  Name                         E-mail Attendee Status
# count              71                             71              71
# unique             71                             71               4
# top     Rob Baltimore  BBaltimore@harriswilliams.com      Checked In
# freq                1                              1              32

# %%
sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             71 non-null     object
#  1   E-mail           71 non-null     object
#  2   Attendee Status  71 non-null     object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
print(sheet["Attendee Status"].unique())
# Out:
# ["RSVP'd" 'Declined' 'Checked In' 'No Show']
