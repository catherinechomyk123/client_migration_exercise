# %% [markdown]
# # Consumer Retail and Healthcare Deal Table
#
# ## As is
#  - Did not have much time to go through it - just eyeballed the data

# %%
import pandas as pd

# %%
path = "..\data\Consumer Retail and Healthcare Pipeline.xlsx"
cr_pipeline = pd.read_excel(path, skiprows=8) # Headers at 8 data at 9

# %%
display(cr_pipeline)
# Out:
#      Unnamed: 0                                       Company Name  \
# 0           NaN                                       Acima Credit
# 1           NaN                                              Array
# 2           NaN                Electrical Components International
# 3           NaN                                European Wax Center
# 4           NaN                                      Guitar Center
# ..          ...                                                ...
# 353         NaN                                                NaN
# 354         NaN                                                NaN
# 355         NaN                                                NaN
# 356         NaN                                          Footnote:
# 357         NaN  (1) Dead includes both failed auctions and dea...
#
#     Project Name Date Added        Invest. Bank  \
# 0            NaN 2018-01-23                 NaN
# 1          Maple 2017-09-01    Jefferies; Baird
# ...

# %%
print(cr_pipeline["Status"].unique())
# Out:
# ['Active' 'Passed/Dead' 'Add On' 'Portfolio Company' nan]
